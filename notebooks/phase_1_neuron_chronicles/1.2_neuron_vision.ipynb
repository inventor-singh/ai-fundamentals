# %% [markdown]
# # 🎨 Level 1.2: The Neuron's Vision
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/YOUR_USERNAME/ai-mastery-from-scratch/blob/main/notebooks/phase_1_neuron_chronicles/1.2_neuron_vision.ipynb)
#
# ---
#
# ## 🎯 **The Challenge**
# **How does a neuron "see" data?**
#
# In this lesson, you'll discover the geometric intuition behind AI. We'll visualize how a single neuron draws a decision boundary in 2D space, and you'll interactively explore how changing weights and bias changes what the neuron "sees."
#
# ### **What You'll Discover:**
# - 🖼️ The geometry of a neuron's decision
# - 🎨 Beautiful 2D plots of decision boundaries
# - 🧠 How weights and bias shape a neuron's vision
# - 🕹️ Interactive exploration of neuron parameters
#
# ### **What You'll Build:**
# An interactive neuron decision explorer!
#
# ---
#
# ## 🚀 **Setup & Installation**
#
# *Run the cell below to set up your environment. This works in both Google Colab and local Jupyter notebooks.*

# %%
# 📦 Install Required Packages
# !pip install numpy --quiet
# !pip install matplotlib --quiet
# !pip install seaborn --quiet
# !pip install ipywidgets --quiet

print("✅ All packages installed!")
# Out:
# ✅ All packages installed!

# %%
# 🔧 Environment Check & Imports
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ipywidgets as widgets
from IPython.display import display

plt.style.use('default')
sns.set_palette("husl")
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 12

print("🎯 Environment ready!")
# Out:
# 🎯 Environment ready!

# %% [markdown]
# ## 🧩 NumPy Fundamentals: The Building Blocks of AI
#
# NumPy is the foundation of numerical computing in Python and is essential for AI and data science. Here are the key concepts you need to know:
#
# - **Arrays:** NumPy's main object is the `ndarray`, a fast, flexible container for large data sets of numbers.
# - **Shape:** The shape of an array tells you its dimensions (rows, columns, etc.).
# - **Vectorized Operations:** NumPy lets you perform operations on entire arrays at once, making code faster and more readable.
# - **Indexing & Slicing:** You can access and modify parts of arrays easily.
# - **Broadcasting:** NumPy can automatically expand arrays of different shapes to work together in operations.
#
# Let's see these in action with some simple examples!

# %% [markdown]
# ## 🧠 Section 1: Visualizing the Neuron's Decision Boundary
#
# A single neuron in 2D draws a straight line to separate classes. Let's see this in action!

# %%
# Generate synthetic 2D data (two classes)
np.random.seed(42)
num_points = 100
X_class0 = np.random.randn(num_points, 2) - 1.5
X_class1 = np.random.randn(num_points, 2) + 1.5
X = np.vstack([X_class0, X_class1])
y = np.array([0]*num_points + [1]*num_points)

plt.scatter(X[:,0], X[:,1], c=y, cmap='coolwarm', edgecolors='k', s=60, alpha=0.7)
plt.title('Sample Data: Two Classes')
plt.xlabel('X1')
plt.ylabel('X2')
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ## 🔬 Section 2: The Neuron's Formula in 2D
#
# A neuron's output:
#
# ```
# output = sigmoid(w1 * x1 + w2 * x2 + b)
# ```
#
# The decision boundary is where output = 0.5 (i.e., the neuron is "undecided").
# Let's plot this boundary for different weights and bias.

# %%
def plot_decision_boundary(w1, w2, b):
    # Plot data
    plt.scatter(X[:,0], X[:,1], c=y, cmap='coolwarm', edgecolors='k', s=60, alpha=0.7)
    
    # Plot decision boundary: w1*x1 + w2*x2 + b = 0
    x_vals = np.linspace(X[:,0].min()-1, X[:,0].max()+1, 100)
    if w2 != 0:
        y_vals = -(w1 * x_vals + b) / w2
        plt.plot(x_vals, y_vals, 'k--', linewidth=2, label='Decision Boundary')
    else:
        plt.axvline(-b/w1, color='k', linestyle='--', linewidth=2, label='Decision Boundary')
    
    plt.title(f"Neuron Decision Boundary\n(w1={w1:.2f}, w2={w2:.2f}, b={b:.2f})")
    plt.xlabel('X1')
    plt.ylabel('X2')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()

# Example: Try w1=1, w2=1, b=0
plot_decision_boundary(1, 3, 0)

# %% [markdown]
# ## 🕹️ Section 3: Interactive Neuron Explorer
#
# Use the sliders to change the neuron's weights and bias. Watch how the decision boundary moves!

# %%
w1_slider = widgets.FloatSlider(value=1, min=-5, max=5, step=0.1, description='w1')
w2_slider = widgets.FloatSlider(value=1, min=-5, max=5, step=0.1, description='w2')
b_slider = widgets.FloatSlider(value=0, min=-5, max=5, step=0.1, description='bias')

ui = widgets.HBox([w1_slider, w2_slider, b_slider])

def interactive_plot(w1, w2, b):
    plot_decision_boundary(w1, w2, b)

out = widgets.interactive_output(interactive_plot, {'w1': w1_slider, 'w2': w2_slider, 'b': b_slider})
display(ui, out)
# Out:
# ...
# Output()

# %% [markdown]
# ## 💡 Section 4: The Aha Moment
#
# - The neuron "sees" the world as a straight line in 2D.
# - Changing weights and bias rotates and shifts this line.
# - This is the geometric intuition behind how a neuron makes decisions!
#
# **Try different values above and see how the boundary changes.**

# %% [markdown]
# ## 🎮 Section 5: Practice
#
# - Can you find weights and bias that perfectly separate the two classes?
# - What happens if you set both weights to zero?
# - Try negative values for weights and bias!

# %% [markdown]
# ## 🌉 Section 6: Bridge to the Next Lesson
#
# In the next lesson, we'll see why a single neuron can't solve everything. Get ready for the famous XOR problem and the need for multi-layer networks!
#
# [Next: Level 1.3 - The Great XOR Crisis →](1.3_xor_crisis.ipynb)
